# %% [markdown]
# # Семинар 1. Программные инструменты для реализации нейросетевых моделей. Pytorch.

# %% [markdown]
# ## Средства разработки
# ### JupyterLab
# - https://jupyter.org
# - Инструмент исследователя
# - Web-based application
# - Сервер можно развернуть где угодно, доступ через браузер
# - Доступ к файловой системе, командной строке, редактирование
# исходного кода, запуск jupyter-тетрадок
# ![](https://sparkcdneus2.azureedge.net/sparkimageassets/XP9KHM4BK9FZ7Q-63e59db4-cf83-46b7-9365-0c37221b94dehttps://miro.medium.com/max/640/1*MGcLJS1ZvMFcBA94PXn16Q.webp)
#
# ### VSCode
# - https://code.visualstudio.com, https://code.visualstudio.com/docs/remote/remote-overview
# - Редактор кода
# - Desktop application
# - Есть расширение для Remote Development
# - Доступ к файловой системе, командной строке, редактирование
# исходного кода, запуск под отладчиком, запуск jupyter-тетрадок,
# code completion, linting
#
# ### PyCharm
#
# - https://www.jetbrains.com/ru-ru/pycharm
# - Python IDE
# - Desktop application
# - Встроенная возможность Remote Development
# - Бесплатная Pro версия для студентов https://www.jetbrains.com/shop/eform/students
#
# ### Google Colab
#
# - https://colab.research.google.com/
# - Доступ через браузер
# - Легко поделиться блокнотом
# - Не нужны вычислительные ресурсы
# - Можно использовать GPU мощности
# - Не требуется настраивать

# %% [markdown]
# ## Средства виртуализации
# ### Anaconda
#
# - https://www.anaconda.com
# - Виртуальное окружение
# - После активации conda environment становятся видны python-
# пакеты и другие библиотеки
# - environment.yaml - описание окружения
# - Лист с командами https://docs.conda.io/projects/conda/en/latest/_downloads/843d9e0198f2a193a3484886fa28163c/conda-cheatsheet.pdf
# - Miniconda https://docs.conda.io/en/latest/miniconda.html
#
# ### Docker
#
# - https://www.docker.com
# - Образ системы
# - Контейнер содержит все пакеты, библиотеки, утилиты
# - Dockerfile - инструкции по созданию образа
# - Пример использования - https://github.com/cds-mipt/airi_cv_2022/tree/master/seminar_1

# %%
# conda create -n hse_2023 python=3.10
# conda install pytorch torchvision torchaudio pytorch-cuda=11.6 -c pytorch -c nvidia
# conda install -c conda-forge jupyterlab
# conda activate hse_2023

# %% [markdown]
# ## Контроль версий и совместная разработка
# ### Git & GitHub
# - Основы работы с Git:
#     1. https://git-scm.com/book/en/v2/Git-Basics-Getting-a-Git-Repository
#     2. https://git-scm.com/book/en/v2/Getting-Started-About-Version-Control
#     3. https://git-scm.com/book/en/v2/Git-Branching-Branches-in-a-Nutshell
# - Список команд https://training.github.com/downloads/github-git-cheat-sheet.pdf
# - Используйте встроенный в IDE функционал для Git/GitHub

# %% [markdown]
# ## Советы при разработке
# - Используйте комбинации клавиш при работе в IDE
# - Vim (MIT) https://www.youtube.com/watch?v=a6Q8Na575qc
#     - Текстовая лекция https://missing.csail.mit.edu/2020/editors/
# - Слепая печать https://www.typingclub.com/sportal/program-3.game
# - Научитесь использовать bash команды

# %% [markdown]
# ## Где взять готовый код

# %% [markdown]
# [Статьи с кодом](https://paperswithcode.com/)
#
# [Готовые модели](https://huggingface.co/models)
#
# [Kaggle](https://www.kaggle.com/competitions)
#
# [PyTorch Hub](https://pytorch.org/hub/)

# %% [markdown]
# ## Получение информации об оборудовании
# Windows - GUI
#
# Linux (Gooble Colab) - terminal

# %%
# Информация о версии Linux
# !cat /proc/version
# Out:
# Linux version 5.15.120+ (builder@ed0d1b4285f6) (Chromium OS 15.0_pre458507_p20220602-r18 clang version 15.0.0 (/var/tmp/portage/sys-devel/llvm-15.0_pre458507_p20220602-r18/work/llvm-15.0_pre458507_p20220602/clang a58d0af058038595c93de961b725f86997cf8d4a), LLD 15.0.0) #1 SMP Wed Aug 30 11:19:59 UTC 2023

# %%
# Информация о версии дистрибутива Linux
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.2 LTS
# Release:	22.04
# Codename:	jammy

# %%
# Информация о видеокарте (Nvidia)
# !nvidia-smi
# Out:
# Fri Oct 13 14:51:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   76C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# CUDA Version в nvidia-smi - это не ваша текущая версия CUDA, а [максимально поддерживаемая версия](https://docs.nvidia.com/cuda/cuda-toolkit-release-notes/index.html) для текущего драйвера видеокарты.

# %%
# cuda compiler
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# Информация о процессоре
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.148
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %%
# Второй вариант получить информацию о процессоре
# !lscpu
# Out:
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         46 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  2
#   On-line CPU(s) list:   0,1
# Vendor ID:               GenuineIntel
#   Model name:            Intel(R) Xeon(R) CPU @ 2.00GHz
#     CPU family:          6
#     Model:               85
#     Thread(s) per core:  2
#     Core(s) per socket:  1
#     Socket(s):           1
#     Stepping:            3
#     BogoMIPS:            4000.29
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscal
#                          l nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopo
#                          logy nonstop_tsc cpuid tsc_known_freq pni pclmulqdq sss
#                          e3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes
# ...

# %%
# Информация о оперативной памяти
# !grep MemTotal /proc/meminfo
# Out:
# MemTotal:       13294208 kB

# %%
# Информация о загруженности диска
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          79G   27G   52G  35% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.1G  885M  55% /usr/sbin/docker-init
# tmpfs           6.4G   31M  6.4G   1% /var/colab
# /dev/sda1        50G   30G   21G  59% /opt/bin/.nvidia
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# Сведения о занимаемом месте на диске
# !du -sh
# !du -h
# !du -h --max-depth=1
# !du -h | sort -h
# Out:
# 55M	.
# 8.0K	./.config/configurations
# 72K	./.config/logs/2023.10.11
# 76K	./.config/logs
# 120K	./.config
# 55M	./sample_data
# 55M	.
# 120K	./.config
# 55M	./sample_data
# 55M	.
# 8.0K	./.config/configurations
# 72K	./.config/logs/2023.10.11
# 76K	./.config/logs
# 120K	./.config
# 55M	.
# 55M	./sample_data

# %%
# права в Google Colab
# !whoami
# Out:
# root

# %% [markdown]
# ## Pytorch
# ### Установка
#
# Ссылки для установки под ваше оборудование можно найти [тут](https://pytorch.org/get-started/locally/).

# %%
import torch
print(torch.__version__)
torch.cuda.is_available()
# Out:
# 2.0.1+cu118
# True

# %%
# !python -m pip list | grep torch
# Out:
# pytorch-lightning                2.1.0
# torch                            2.0.1+cu118
# torchaudio                       2.0.2+cu118
# torchdata                        0.6.1
# torchmetrics                     1.2.0
# torchsummary                     1.5.1
# torchtext                        0.15.2
# torchvision                      0.15.2+cu118

# %% [markdown]
# ### Тензоры

# %%
a = torch.Tensor([1,2,3])
a
# Out:
# tensor([1., 2., 3.])

# %%
b = torch.tensor([1,2,3])
b
# Out:
# tensor([1, 2, 3])

# %%
a.dtype, b.dtype
# Out:
# (torch.float32, torch.int64)

# %%
c = b.float()

print(c, c.dtype)

print(c.int(), c.int().dtype)
print(c.long(), c.long().dtype)
print(c.double(), c.double().dtype)
# Out:
# tensor([1., 2., 3.]) torch.float32
# tensor([1, 2, 3], dtype=torch.int32) torch.int32
# tensor([1, 2, 3]) torch.int64
# tensor([1., 2., 3.], dtype=torch.float64) torch.float64

# %%
# Двумерный тензор
x = torch.rand(2, 3)
print(x)
print(x.device)
print(x.dtype)
# Out:
# tensor([[0.7332, 0.7528, 0.0921],
#         [0.3846, 0.2138, 0.2666]])
# cpu
# torch.float32

# %%
x = torch.zeros(2, 3)
x = torch.zeros_like(x)
x = torch.ones(2, 3)
x = torch.ones_like(x)

# %% [markdown]
# The function torch.Tensor allocates memory for the desired tensor, but reuses any values that have already been in the memory. To directly assign values to the tensor during initialization, there are many alternatives including:
#
# - `torch.zeros`: Creates a tensor filled with zeros
#
# - `torch.ones`: Creates a tensor filled with ones
#
# - `torch.rand`: Creates a tensor with random values uniformly sampled between 0 and 1
#
# - `torch.randn`: Creates a tensor with random values sampled from a normal distribution with mean 0 and variance 1
#
# - `torch.arange`: Creates a tensor containing the values
#
# - `torch.Tensor` (input list): Creates a tensor from the list elements you provide

# %% [markdown]
# ### Воспроизводимость результатов

# %%
# для воспроизводимости результатов
# не изменяйте и не удаляйте этот код
from numpy.random import seed
import random

random.seed(0)
seed(0)
torch.manual_seed(0)

# %% [markdown]
# Подробнее можно прочитать [тут](https://pytorch.org/docs/stable/notes/randomness.html).

# %%
# !pip install pytorch-lightning -qqq

# %%
import pytorch_lightning as pl
# Function that sets seed for pseudo-random
# number generators in: pytorch, numpy, python.random
pl.seed_everything(0, workers=True)
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 0
# 0

# %% [markdown]
# ### CUDA

# %%
import torch
import time

# проверка доступности видеокарты, выбор устройства CPU или GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# Большая матрица
x = torch.randn(5000, 5000)

## Версия для процессора
start_time = time.time()
_ = torch.matmul(x, x)
end_time = time.time()
print(f"CPU time: {(end_time - start_time):6.5f}s")


## Версия для видеокарты
x = x.to(device)
_ = torch.matmul(x, x)  # Первая операция нужна, чтобы прогреть GPU

# CUDA работает асинхронно, поэтому будем использовать другие функции для вычисления времени
start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)
start.record()
_ = torch.matmul(x, x)
end.record()
torch.cuda.synchronize()  # Ждем, пока все посчитается на GPU
print(f"GPU time: {0.001 * start.elapsed_time(end):6.5f}s")  # Милисекунды в секунды
# Out:
# CPU time: 2.67096s
# GPU time: 0.08762s

# %%
del _

# %%
# проверка доступности видеокарты, выбор устройства CPU или GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# Данные нужно вручную переносить в видеопамять -- метод cuda. Перенос в оперативную память -- cpu. Альтернатива -- использование метода `.to(device)`. По умолчанию данные на cpu.

# %%
d = c.to(device)

# %%
torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# !nvidia-smi
# Out:
# Fri Oct 13 14:51:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    63W /  70W |   1101MiB / 15360MiB |     87%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Человеко-читаемый размер в байтах
def sizeof_fmt(num, suffix="B"):
    for unit in ["", "Ki", "Mi", "Gi", "Ti", "Pi", "Ei", "Zi"]:
        if abs(num) < 1024.0:
            return f"{num:3.1f}{unit}{suffix}"
        num /= 1024.0
    return f"{num:.1f}Yi{suffix}"

# %%
def allocate_empty_tensor(dim_size):
    a = torch.zeros(4096, dim_size, dtype=torch.float32, device='cuda')

# %%
# !nvidia-smi
# Out:
# Fri Oct 13 14:51:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    36W /  70W |   1101MiB / 15360MiB |     87%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
allocate_empty_tensor(2048)

# %%
alloc = torch.cuda.memory_allocated()
sizeof_fmt(alloc)
# Out:
# '104.1MiB'

# %%
reserved = torch.cuda.memory_reserved()
sizeof_fmt(reserved)
# Out:
# '310.0MiB'

# %%
# !nvidia-smi
# Out:
# Fri Oct 13 14:51:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    36W /  70W |   1101MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
allocate_empty_tensor(3072)

# %%
alloc = torch.cuda.memory_allocated()
sizeof_fmt(alloc)
# Out:
# '104.1MiB'

# %%
reserved = torch.cuda.memory_reserved()
sizeof_fmt(reserved)
# Out:
# '310.0MiB'

# %%
# !nvidia-smi
# Out:
# Fri Oct 13 14:51:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    36W /  70W |   1101MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
alloc = torch.cuda.memory_allocated()
print(sizeof_fmt(alloc))
reserved = torch.cuda.memory_reserved()
print(sizeof_fmt(reserved))
# Out:
# 104.1MiB
# 310.0MiB

# %%
# !nvidia-smi
# Out:
# Fri Oct 13 14:51:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    36W /  70W |   1101MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ### Точность

# %% [markdown]
# Вывод: В разных библиотеках, средах или на разных устройствах может сильно отличаться точность вычислений с плавающей точкой. Довольно сложно решить эту проблему полностью.
#
# Однако обратите внимание, что относительная ошибка достаточно мала, что делает такие различия менее значимими в случае глубокого обучения.

# %%
import numpy as np


torch.manual_seed(1337)
x = torch.randn(5000, 5000)

def matrix_power(x):
  y = x @ x @ x @ x @ x @ x
  return (y).sum().item()

print(matrix_power(x))
print(matrix_power(x.cuda()))
print(matrix_power(x.numpy()))
print(np.linalg.matrix_power(x.numpy(),6).sum())
# Out:
# 27654770130944.0
# 27654807879680.0
# 27654749159424.0
# 27654760000000.0

# %% [markdown]
# ## Нейроны и линейные слои

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1k96ch-5lAGYrfBk4xgoty93xy-GP2bhr)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1ORawq1pZJ7a2z7vUD2PPyLELkOHoAB51)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
n_customers = 2 # Количество покупателей
n_items = 4          # Количество существующих товаров
n_shops = 3          # Количество существующих магазинов

# Матрица покупателей
X = torch.rand(n_customers, n_items)

# Матрица цен в магазине
W = torch.rand(n_shops, n_items)

# Цена за топливо
b = torch.rand(n_shops)

print(X.shape, W.shape, b.shape)
print(X)

answer = X @ W.T + b
answer.shape
# Out:
# torch.Size([2, 4]) torch.Size([3, 4]) torch.Size([3])
# tensor([[0.5997, 0.7686, 0.8438, 0.6866],
#         [0.9745, 0.5593, 0.4227, 0.4468]])
# torch.Size([2, 3])

# %%
import torch.nn as nn
from torch import nn

linear = nn.Linear(4, 3)
out = linear(X)
out.shape
# Out:
# torch.Size([2, 3])

# %% [markdown]
# [Линейный слой в Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)

# %%
weights_shape = linear.weight.data.shape
print(f"Weights shape: {weights_shape}")
bias_shape = linear.bias.data.shape
print(f"Bias shape: {bias_shape}")
# Out:
# Weights shape: torch.Size([3, 4])
# Bias shape: torch.Size([3])

# %% [markdown]
# ### Встроенные слои

# %%
from torch import nn # модуль с базовыми слоями
import torch.nn.functional as F # модуль с базовыми функциями

# %%
import pprint

# %%
pprint.pprint(dir(nn))
# Out:
# ['AdaptiveAvgPool1d',
#  'AdaptiveAvgPool2d',
#  'AdaptiveAvgPool3d',
#  'AdaptiveLogSoftmaxWithLoss',
#  'AdaptiveMaxPool1d',
#  'AdaptiveMaxPool2d',
#  'AdaptiveMaxPool3d',
#  'AlphaDropout',
#  'AvgPool1d',
#  'AvgPool2d',
#  'AvgPool3d',
#  'BCELoss',
#  'BCEWithLogitsLoss',
#  'BatchNorm1d',
#  'BatchNorm2d',
#  'BatchNorm3d',
#  'Bilinear',
#  'CELU',
#  'CTCLoss',
#  'ChannelShuffle',
#  'ConstantPad1d',
#  'ConstantPad2d',
#  'ConstantPad3d',
#  'Container',
#  'Conv1d',
#  'Conv2d',
#  'Conv3d',
#  'ConvTranspose1d',
#  'ConvTranspose2d',
#  'ConvTranspose3d',
#  'CosineEmbeddingLoss',
#  'CosineSimilarity',
#  'CrossEntropyLoss',
#  'CrossMapLRN2d',
#  'DataParallel',
#  'Dropout',
#  'Dropout1d',
#  'Dropout2d',
#  'Dropout3d',
#  'ELU',
#  'Embedding',
#  'EmbeddingBag',
#  'FeatureAlphaDropout',
#  'Flatten',
#  'Fold',
#  'FractionalMaxPool2d',
#  'FractionalMaxPool3d',
#  'GELU',
#  'GLU',
#  'GRU',
#  'GRUCell',
#  'GaussianNLLLoss',
#  'GroupNorm',
#  'Hardshrink',
# ...

# %%
len(dir(nn))
# Out:
# 181

# %% [markdown]
# Два способа создания нейросети:
#   1. на основе готового класса `nn.Sequential` объединяющего отдельные слои
#     - данные передаются по сети в том порядке, в каком объявлены слои
#     - функции активации задаются как отдельные слои
#   2. свой класс для нейросети, на основе `nn.Module`
#     - порядок передачи данных можно менять во время обучения, переопределив forward - динамический граф вычислений
#
# Первый способ стоит использовать только как контейнер для ряда слоев. Неросеть нужно наследовать от `nn.Module`.

# %%
net_seq = nn.Sequential(
    nn.Linear(in_features=3, out_features=5),
    nn.Sigmoid(),
    nn.Linear(in_features=5, out_features=2),
)
net_seq.to(device)
net_seq
# Out:
# Sequential(
#   (0): Linear(in_features=3, out_features=5, bias=True)
#   (1): Sigmoid()
#   (2): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(in_features=3, out_features=5)
        self.fc2 = nn.Linear(in_features=5, out_features=2)

    def forward(self, x):
        x = self.fc1(x)
        return F.sigmoid(self.fc2(x))

# %%
net_model = Model()
net_model.to(device)
net_model
# Out:
# Model(
#   (fc1): Linear(in_features=3, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=2, bias=True)
# )

# %% [markdown]
# ## Модели в Pytorch

# %%
import torch
from torch import nn

# %%
# Смоделируем данные

batch_size = 5
n_features = 10  # Количество признаков
n_classes = 3  # Количество классов


data = torch.randn((batch_size, n_features))
print(data.shape)
print(data)
# Out:
# torch.Size([5, 10])
# tensor([[-0.0177,  1.4726,  0.3218,  0.8926, -1.1759,  0.6895,  0.5443,  1.7796,
#           1.2393,  0.4219],
#         [-1.2182,  0.8278, -0.4991, -0.9674,  0.5914,  0.2598, -0.4846, -1.0455,
#           0.7438, -0.1378],
#         [ 0.8573,  0.8459, -0.5569,  0.6975, -1.2282,  0.4947,  0.3576,  1.2712,
#           0.9722, -0.1017],
#         [-0.2905,  1.4713,  2.6283,  0.3943, -0.2970,  0.7051, -0.8222, -0.4577,
#          -1.1704,  0.0247],
#         [ 1.4754, -1.5184,  2.5516,  0.7347, -0.7239, -0.2576,  2.0135,  0.2755,
#          -0.1061,  1.6577]])

# %%
# Зададим простую модель
model = nn.Linear(n_features, n_classes)

# %%
# Применим модель к вектору
answer = model(data)
print(answer.shape)
print(answer)
# Out:
# torch.Size([5, 3])
# tensor([[ 0.8792,  0.4823,  0.2387],
#         [-0.1066, -0.2331,  0.5826],
#         [ 0.8920,  0.0577,  0.2108],
#         [-0.5591, -0.3591, -0.0473],
#         [ 0.6473,  0.1904, -1.5058]], grad_fn=<AddmmBackward0>)

# %%
# Модель как наследник nn.Module
class SimpleNN(nn.Module):
    def __init__(self, n_features, n_classes):
        super().__init__()

        self.lin = nn.Linear(n_features, n_classes)

    def forward(self, x):
        return self.lin(x)

# %%
# Попробуем применить модель в виде класса к данным
model = SimpleNN(n_features, n_classes)

answer = model(data)
print(answer.shape)
print(answer)
# Out:
# torch.Size([5, 3])
# tensor([[-3.6320e-01,  1.0883e-01, -3.6103e-01],
#         [-1.9715e-01, -6.0217e-01, -6.5864e-01],
#         [ 1.5124e-01,  1.3275e-03, -6.2486e-01],
#         [-1.4151e+00,  6.7493e-01, -1.6122e-01],
#         [ 4.4988e-02,  1.0709e+00,  8.9614e-01]], grad_fn=<AddmmBackward0>)

# %%
# !pip install torchsummary
from torchsummary import summary

model = SimpleNN(n_features, n_classes).cuda()

# 5, 10
input_size = (batch_size, n_features)
print(summary(model, input_size))
# Out:
# ...
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                 [-1, 5, 3]              33
# ...
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# None

# %%
# Модель как sequential
model = nn.Sequential(nn.Linear(n_features, n_classes))

answer = model(data)
print(answer.shape)
print(answer)
# Out:
# torch.Size([5, 3])
# tensor([[ 0.6500,  0.7611,  0.8854],
#         [-0.0789,  0.0683, -0.6099],
#         [ 0.1682,  0.4332,  0.4686],
#         [ 0.7563,  1.1796,  0.9124],
#         [ 0.2209, -0.4888,  0.5770]], grad_fn=<AddmmBackward0>)

# %%
# Модель как nn.ModuleList

model = nn.ModuleList([nn.Linear(n_features, n_classes)])

# answer = model(data)
# print(answer.shape)
# print(answer)

answer = model[0](data)
print(answer.shape)
print(answer)
# Out:
# torch.Size([5, 3])
# tensor([[ 0.2296,  0.9783,  0.4379],
#         [-0.0689, -0.5371, -0.0373],
#         [ 0.3182,  0.7609,  0.4510],
#         [ 0.9051, -0.7152, -0.2857],
#         [ 0.0283,  1.8521, -0.0429]], grad_fn=<AddmmBackward0>)

# %%
# Проверим параметры модели
class ParametersCheck(nn.Module):
    def __init__(self, n_features, n_classes):
        super().__init__()

        self.lin = nn.Linear(n_features, n_classes)
        self.seq = nn.Sequential(nn.Linear(n_features, n_classes))
        self.module_list = nn.ModuleList([nn.Linear(n_features, n_classes)])
        self.list_of_layers = [nn.Linear(n_features, n_classes)]
        self.parameter = nn.Parameter(data=torch.Tensor([1]))

# %%
model = ParametersCheck(n_features, n_classes)

for i, param in enumerate(model.parameters()):
    print(f'Параметр #{i + 1}.')
    print(f'\t{param.shape}')
# Out:
# Параметр #1.
# 	torch.Size([1])
# Параметр #2.
# 	torch.Size([3, 10])
# Параметр #3.
# 	torch.Size([3])
# Параметр #4.
# 	torch.Size([3, 10])
# Параметр #5.
# 	torch.Size([3])
# Параметр #6.
# 	torch.Size([3, 10])
# Параметр #7.
# 	torch.Size([3])

# %% [markdown]
# ## Рекомендуемые ссылки
# ### Курсы
#
# - [Нейронные сети и компьютерное зрение, Samsung AI Center, часть 1](https://stepik.org/course/50352/syllabus)
#
# - [Deep Learning School](https://vk.com/dlschool_mipt)
#
# - [CS231n Convolutional Neural Networks for Visual Recognition](https://cs231n.github.io/)
#
# - [Машинное обучение (Радослав Нейчаев)](https://www.youtube.com/playlist?list=PL4_hYwCyhAvasRqzz4w562ce0esEwS0Mt)
#
# - [Эффективные системы глубокого обучения (ШАД, HSE)](https://github.com/mryab/efficient-dl-systems/tree/2022)
#
# ### Разное
#
# - [Cимулятор](https://playground.tensorflow.org/) нейронов и нейронных сетей
# - [Пример](https://github.com/openai/whisper) хорошего кода

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## **Задача 1**.
# Посчитайте количество обучаемых параметров в сети net_seq и net_model.

# %%
batch_size = 2
n_features = 3



x = torch.randn((batch_size, n_features)).cuda()

net_seq = nn.Sequential(
    nn.Linear(in_features=3, out_features=5),
    nn.Sigmoid(),
    nn.Linear(in_features=5, out_features=2),
)
net_seq.to(device)
net_seq
# Out:
# Sequential(
#   (0): Linear(in_features=3, out_features=5, bias=True)
#   (1): Sigmoid()
#   (2): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
net_seq(x)
# Out:
# tensor([[-0.4985, -0.3323],
#         [-0.6522, -0.3982]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
input_size = (batch_size, n_features)
print(summary(net_seq, input_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                 [-1, 2, 5]              20
#            Sigmoid-2                 [-1, 2, 5]               0
#             Linear-3                 [-1, 2, 2]              12
# ...
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# None

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(in_features=3, out_features=5)
        self.fc2 = nn.Linear(in_features=5, out_features=2)

    def forward(self, x):
        x = self.fc1(x)
        return F.sigmoid(self.fc2(x))

# %%
net_model = Model()
net_model.to(device)
net_model
# Out:
# Model(
#   (fc1): Linear(in_features=3, out_features=5, bias=True)
#   (fc2): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
input_size = (batch_size, n_features)
print(summary(net_model, input_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                 [-1, 2, 5]              20
#             Linear-2                 [-1, 2, 2]              12
# ...
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# None

# %%
#answer
in_features_1=3
out_features_1=5
in_features_2=5
out_features_2=2
in_features_1*out_features_1+out_features_1+in_features_2*out_features_2+out_features_2
# Out:
# 32

# %% [markdown]
# ## **Задача 2**.
# 1. Нарисуйте backward граф для выражения `a*b+c*d`. [Теория и пример оформления](https://www.youtube.com/watch?v=MswxJw-8PvE).
#
# 2. Сравните полученные теоретические значения с аттрибутами grad у исходных тензоров.
#
# 3. Загрузите полученную картинку в формате `.pdf` в репозиторий

# %%
a = torch.tensor([2.0], requires_grad=True)
b = torch.tensor([4.0], requires_grad=True)
c = torch.tensor([1.0], requires_grad=True)
d = torch.tensor([5.0], requires_grad=False)

# %%
print(a.grad)
# Out:
# None

# %%
loss = a*b + c*d
loss.backward()
loss
# Out:
# tensor([13.], grad_fn=<AddBackward0>)

# %%
print('a', a.grad)
print('b', b.grad)
print('c', c.grad)
print('d', d.grad)
# Out:
# a tensor([4.])
# b tensor([2.])
# c tensor([5.])
# d None

# %% [markdown]
# #### Вспомогательная функция для отображения параметров тензора

# %%
import torch

# %%
def show_tensor_params(*tensors):
  for x in tensors:
    print('---')
    print(f"data - {x.data}")
    print(f"grad - {x.grad}")
    print(f"grad_fn - {x.grad_fn}")
    print(f"req_grad - {x.requires_grad}")
    print(f"is_leaf - {x.is_leaf}")

# %%
x = torch.tensor(5.0)
show_tensor_params(x)
# Out:
# ---
# data - 5.0
# grad - None
# grad_fn - None
# req_grad - False
# is_leaf - True

# %% [markdown]
# ![pytorch_graph.png](data:image/png;base64,...)

# %% [markdown]
# ## **Задача 2**. Cделать нейрон, соответствующий оператору НЕ.

# %%
import numpy as np
import torch

# %%
class Neuron(torch.nn.Module):
  def __init__(self):
    super().__init__()
    self.fc = torch.nn.Linear(1, 1)

  def forward(self, x):
    return torch.heaviside(self.fc(x), torch.tensor([0.0]))

# %%
neuron = Neuron()
neuron.fc.weight, neuron.fc.bias
# Out:
# (Parameter containing:
#  tensor([[0.7846]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.3533], requires_grad=True))

# %%
neuron.fc.weight.data = torch.tensor([[-1.0]])
neuron.fc.bias.data = torch.tensor([1.0])

# %%
x = torch.tensor([0.0])
print(x, neuron(x))
x = torch.tensor([1.0])
print(x, neuron(x))
# Out:
# tensor([0.]) tensor([1.], grad_fn=<NotImplemented>)
# tensor([1.]) tensor([0.], grad_fn=<NotImplemented>)

# %% [markdown]
# ## **Задача 3**. Cделать нейрон, соответствующий оператору И.

# %%
class Neuron(torch.nn.Module):
  def __init__(self):
    super().__init__()
    self.fc = torch.nn.Linear(2, 1)

  def forward(self, x):
    return torch.heaviside(self.fc(x), torch.tensor([0.0]))

# %%
neuron = Neuron()
neuron.fc.weight, neuron.fc.bias
# Out:
# (Parameter containing:
#  tensor([[ 0.1561, -0.2052]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.6921], requires_grad=True))

# %%
neuron.fc.weight.data = torch.tensor([[1.0, 1.0]])
neuron.fc.bias.data = torch.tensor([-1.0])

# %%
x = torch.tensor([0.0, 0.0])
print(x, neuron(x))
x = torch.tensor([0.0, 1.0])
print(x, neuron(x))
x = torch.tensor([1.0, 0.0])
print(x, neuron(x))
x = torch.tensor([1.0, 1.0])
print(x, neuron(x))
# Out:
# tensor([0., 0.]) tensor([0.], grad_fn=<NotImplemented>)
# tensor([0., 1.]) tensor([0.], grad_fn=<NotImplemented>)
# tensor([1., 0.]) tensor([0.], grad_fn=<NotImplemented>)
# tensor([1., 1.]) tensor([1.], grad_fn=<NotImplemented>)

# %% [markdown]
# ## **Задача 4**. Cделать нейрон, соответствующий оператору ИЛИ.

# %%
neuron.fc.weight.data = torch.tensor([[0.5, 0.5]])
neuron.fc.bias.data = torch.tensor([0.0])

# %%
x = torch.tensor([0.0, 0.0])
print(x, neuron(x))
x = torch.tensor([0.0, 1.0])
print(x, neuron(x))
x = torch.tensor([1.0, 0.0])
print(x, neuron(x))
x = torch.tensor([1.0, 1.0])
print(x, neuron(x))
# Out:
# tensor([0., 0.]) tensor([0.], grad_fn=<NotImplemented>)
# tensor([0., 1.]) tensor([1.], grad_fn=<NotImplemented>)
# tensor([1., 0.]) tensor([1.], grad_fn=<NotImplemented>)
# tensor([1., 1.]) tensor([1.], grad_fn=<NotImplemented>)

# %% [markdown]
# ## **Задача 5**. Cделать нейрон, соответствующий оператору XOR.

# %%
neuron.fc.weight.data = torch.tensor([[0.0, 0.0]])
neuron.fc.bias.data = torch.tensor([0.0])

# %%
x = torch.tensor([0.0, 0.0])
neuron(x)
# Out:
# tensor([0.], grad_fn=<NotImplemented>)

# %% [markdown]
# нельзя построить на одном нейроне

# %% [markdown]
# ##**Задача 6.**
# Реализуйте XOR с помощью 3 нейронов. Запишите ответ в виде выражения, состоящего из объектов neuron() – моделей нейрона с пороговой функцией активации, внутри скобок может быть что угодно. Входы верхнего уровня называются x1 и x2. Пример фрагмента записи: neuron(1x1 + 5x2 - 0.1) + neuron(x1) (ответ будет выглядеть чуть сложнее, но других символов вроде && не потребуется).

# %%
class Neuron_1(torch.nn.Module):
  def __init__(self):
    super().__init__()
    self.fc = torch.nn.Linear(1, 1)

  def forward(self, x):
    return torch.heaviside(self.fc(x), torch.tensor([0.0]))

class Neuron_2(torch.nn.Module):
  def __init__(self):
    super().__init__()
    self.fc = torch.nn.Linear(2, 1)

  def forward(self, x):
    return torch.heaviside(self.fc(x), torch.tensor([0.0]))

neuron_no = Neuron_1()
neuron_no.fc.weight.data = torch.tensor([[-1.0]])
neuron_no.fc.bias.data = torch.tensor([1.0])

neuron_or = Neuron_2()
neuron.fc.weight.data = torch.tensor([[0.5, 0.5]])
neuron.fc.bias.data = torch.tensor([0.0])

neuron_and = Neuron_2()
neuron_and.fc.weight.data = torch.tensor([[1.0, 1.0]])
neuron_and.fc.bias.data = torch.tensor([-1.0])


x = torch.tensor([0.0, 0.0])


def neuron(x):
  a = neuron_and(torch.tensor([neuron_no(torch.tensor([x.tolist()[0]])), x.tolist()[1]]))

  b = neuron_and(torch.tensor([neuron_no(torch.tensor([x.tolist()[1]])), x.tolist()[0]]))
  return neuron_or(torch.tensor([a,b]))

x = torch.tensor([0.0, 0.0])
print(x, neuron(x))
x = torch.tensor([0.0, 1.0])
print(x, neuron(x))
x = torch.tensor([1.0, 0.0])
print(x, neuron(x))
x = torch.tensor([1.0, 1.0])
print(x, neuron(x))
# Out:
# tensor([0., 0.]) tensor([1.], grad_fn=<NotImplemented>)
# tensor([0., 1.]) tensor([1.], grad_fn=<NotImplemented>)
# tensor([1., 0.]) tensor([1.], grad_fn=<NotImplemented>)
# tensor([1., 1.]) tensor([1.], grad_fn=<NotImplemented>)

# %% [markdown]
# ## **Вопрос 1**.
# Какие нейронные сети могут иметь только линейную разделяющую поверхность?

# %% [markdown]
# нейронная сеть без функций активации или из одного нейрона

# %% [markdown]
# ## **Вопрос 2**.
# Имеет ли смысл соединять полносвязанные нейроны (нейроны, которые принимают на вход все выходы предыдущего слоя) с линейной функцией активации в многослойную нейронную сеть?

# %% [markdown]
# нет, результатом работы такой нейронной сети будет линейная комбинация из входов в нейронную сеть

# %% [markdown]
# ## **Задача 7**.
# Поэксперементируйте с размером тензоров, которые влезут на видеоркарту в Colab. Найдите максимальный размер тензора для типа данных float32, float64, float16, int32, int64. На сколько они отличаются.

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#x = torch.rand(14*2**28, dtype=torch.float32, device=device)
#x = torch.rand(14*2**27, dtype=torch.float64, device=device)
#x = torch.rand(14*2**29, dtype=torch.float16, device=device)
#x = torch.ones(14*2**27, dtype=torch.long, device=device)
x = torch.ones(14*2**28, dtype=torch.int32, device=device)
def sizeof_fmt(num, suffix="B"):
    for unit in ["", "Ki", "Mi", "Gi", "Ti", "Pi", "Ei", "Zi"]:
        if abs(num) < 1024.0:
            return f"{num:3.1f}{unit}{suffix}"
        num /= 1024.0
    return f"{num:.1f}Yi{suffix}"

alloc = torch.cuda.memory_allocated()
print(sizeof_fmt(alloc))
reserved = torch.cuda.memory_reserved()
print(sizeof_fmt(reserved))


# !nvidia-smi
# Out:
# 14.0GiB
# 14.0GiB
# Fri Oct 13 14:52:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    31W /  70W |  14935MiB / 15360MiB |     14%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## **Задача 8**.
# 1. Создайте вектор х, который занимает 10% памяти видеокарты.
#
# 2. Напишите такой код, который заранее займет память на видеокарте, чтобы вызвать ошибку "out of memory" при создании вектора х. При этом свободной, не аллоцированной памяти должно хватать.
#
# Подсказка: поиграйтесь с резервированием памяти

# %%
# Ваш код здесь

# %% [markdown]
# ## **Задача 9**.
# 1. Создайте один линейный слой `nn.Linear` и один входной тензор `x`.
# 2. Подберите размерности так, чтобы они занимали всю видеопамять.
# 3. Попробуйте применить линейный слой к тензору `x`. Что проишло?
# 4. Поиграйтесь с параметрами requires_grad у линейного слоя и у вектора и повторите пункт 3.
# 5. Кратко опишите ваши эксперименты. Что вы поняли?

# %%
# Ваш код здесь

# %% [markdown]
# Ваш ответ здесь
